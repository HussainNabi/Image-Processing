# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import cv2
from skimage import data, img_as_float
from skimage import exposure

# %%
# Load the image in grayscale
img = cv2.imread('image/THUMB.png', cv2.IMREAD_GRAYSCALE)

# Set the threshold values
threshold_values = [0, 50, 100, 150, 200]

# Apply thresholding with different threshold values
for threshold_value in threshold_values:
    ret, thresh = cv2.threshold(img, threshold_value, 255, cv2.THRESH_BINARY)
    cv2.imshow(f'Thresholded Image ({threshold_value})', thresh)

# Display the original image
cv2.imshow('Original Image', img)
cv2.waitKey()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[2], line 10
#       8 for threshold_value in threshold_values:
#       9     ret, thresh = cv2.threshold(img, threshold_value, 255, cv2.THRESH_BINARY)
# ---> 10     cv2.imshow(f'Thresholded Image ({threshold_value})', thresh)
#      12 # Display the original image
#      13 cv2.imshow('Original Image', img)
#
# error: OpenCV(4.13.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:973: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'

# %%
img = data.moon()
cv2.imshow('Original Image', img)
cv2.waitKey()
# Out:
# -1

# %%
# Contrast stretching
p2, p98 = np.percentile(img, (2, 98))
img_rescale = exposure.rescale_intensity(img, in_range=(p2, p98))
cv2.imshow('modified Image', img_rescale)
cv2.waitKey()
# Out:
# -1
